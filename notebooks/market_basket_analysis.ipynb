# %% [markdown]
# # Market Basket Analysis
#
# Dataset: Groceries dataset (9,835 transactions, 169 unique items).
#
# This notebook follows the tracker phases in order. Each phase's code lives in `src/`, imported and run from here.

# %%
import sys
sys.path.append('../src')
import pandas as pd

# %% [markdown]
# ## Phase 2 — Data Loading & EDA

# %%
# TODO: Phase 2

# %% [markdown]
# ## Phase 3 — Transaction Encoding

# %%
# TODO: Phase 3

# %% [markdown]
# ## Phase 4 — Frequent Itemset Mining

# %%
# TODO: Phase 4

# %% [markdown]
# ## Phase 5 — Association Rule Generation

# %%
# TODO: Phase 5

# %% [markdown]
# ## Phase 6 — Visualization & Business Insights

# %%
# TODO: Phase 6
